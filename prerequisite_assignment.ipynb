# %% [markdown]
# # In the dataset give below each record represents one day’s data in the format:
# (study hours, entertainment hours, sleep hours)

# %%
#Dataset :(study,entertainment , sleep)
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# %% [markdown]
# # Task 1: classify study time
# a) create empty lists for study time classifications
# b) iterate over the time_data list and add each study hour to the appropriate category
# c) print the lists to verify the classifications.

# %%
# create empty cells 
low = []
moderate = []
high = []

# iterate over dataset 
for record in time_data:
    study_hours = record[0] 
    if study_hours < 3:
        low.append(study_hours)
    elif 3 <= study_hours <= 5:
        moderate.append(study_hours)
    else:
        high.append(study_hours)

# print results
print("Low study hours;",low)
print("Moderate study hours:",moderate)
print("High study hours:",high)
# Out:
# Low study hours; [2.5, 1.5, 2.0, 2.5]
# Moderate study hours: [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High study hours: [5.5, 6.0]

# %% [markdown]
# # Task 2: find out how many days had low , moderate and high study time

# %%
# Count number of days
days_low = len(low)
days_moderate = len(moderate)
days_high = len(high)

print("Number of days with low study:", days_low)
print("Number of days with moderate study:", days_moderate)
print("Number of days with high study:", days_high)
# Out:
# Number of days with low study: 4
# Number of days with moderate study: 9
# Number of days with high study: 2

# %% [markdown]
# # Task 3: Convert study hours to minutes
# a) Iterate over the time_data and apply the formula
# b) store the results in a new list
# c) print the converted values

# %%
# Create empty list
study_minutes = []

# Convert study hour to minutes
for record in time_data:
    study_hours = record[0]
    minutes = study_hours * 60
    study_minutes.append(minutes)

# Print results
print("Study time in minutes:", study_minutes)
# Out:
# Study time in minutes: [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %% [markdown]
# # Task 4: Analyze average time use
# a) create empty lists for study_hours, entertainment_hours, and sleep_hours.
# b) iterate over time_data and extract values into each list.
# c) Calculate and print average hours spent on studying , entertainment and sleeping.

# %%
# Create empty lists
study_hours = []
entertainment_hours = []
sleep_hours = []

# extract values
for record in time_data:
    study_hours.append(record[0])
    entertainment_hours.append(record[1])
    sleep_hours.append(record[2])

# Calculate averages
avg_study = sum(study_hours) / len(study_hours)
avg_entertainment = sum(entertainment_hours) / len(entertainment_hours)
avg_sleep = sum(sleep_hours) / len(sleep_hours)

print("Average study hours:", avg_study)
print("Average entertainment hours:", avg_entertainment)
print("Average sleep hours:", avg_sleep)
# Out:
# Average study hours: 3.7
# Average entertainment hours: 2.5
# Average sleep hours: 7.166666666666667

# %% [markdown]
# # Task 5. Visualization - Study vs Sleep Pattern:
# 1. Import matplotlib.pyplot as plt.
# 2. Plot a scatter plot with:
# • x-axis: Study hours
# • y-axis: Sleep hours
# 3. Add labels, title, and color.

# %%
import matplotlib.pyplot as plt

plt.scatter(study_hours, sleep_hours, color='purple', s=80)  # s=80 makes dots bigger
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study vs Sleep Pattern of Students")
plt.grid(True)  # optional, adds grid
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # 8.1.1 Task 1: Write a recursive function sum_nested_list(nested_list) that:
# a) Takes a nested list as input.
# b) Sums all numbers at every depth level of the list, regardless of how deeply nested
# the numbers are.
#  Test the function with a sample nested list, such as
# nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
# The result should be the total sum of all the numbers.

# %%
def sum_nested_list(nested_list):
    """
    Recursively calculate the sum of all numbers in a nested list.
    
    Args:
        nested_list (list): List containing integers or other nested lists.
        
    Returns:
        int: Total sum of all integers.
    """
    total = 0
    for element in nested_list:
        if isinstance(element, list):  
            total += sum_nested_list(element)  
        else:
            total += element  # Add number to total
    return total

# Test the function
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
print("Sum of nested list:", sum_nested_list(nested_list))
# Out:
# Sum of nested list: 36

# %% [markdown]
# # Task 2 - Generate All Permutations of a String:
# Scenario: Given a string, generate all possible permutations of its characters. This is useful
# for understanding backtracking and recursive depth-first search.
# Task:
# • Write a recursive function generate_permutations(s) that:
# – Takes a string s as input and returns a list of all unique permutations.
# • Test with strings like ”abc” and ”aab”.
#
# print(generate_permutations("abc"))
# Should return [’abc’, ’acb’, ’bac’, ’bca’, ’cab’, ’cba’]

# %%
def generate_permutations(s):
    """
    Recursively generate all unique permutations of a string.
    
    Args:
        s (str): Input string
        
    Returns:
        list: List of unique permutations
    """
    if len(s) == 1:
        return [s]
    
    permutations = []
    for i, char in enumerate(s):
        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            permutations.append(char + perm)
    
    return list(set(permutations)) 

# Test examples
print("Permutations of 'abc':", generate_permutations("abc"))
print("Permutations of 'aab':", generate_permutations("aab"))
# Out:
# Permutations of 'abc': ['acb', 'abc', 'cba', 'cab', 'bac', 'bca']
# Permutations of 'aab': ['aba', 'baa', 'aab']

# %% [markdown]
# # Task 3 - Directory Size Calculation:
# 1. Write a recursive function calculate_directory_size(directory) where:
# • directory is a dictionary where keys represent file names (with values as sizes in
#
# KB) or directory names (with values as another dictionary representing a subdi-
# rectory).
#
# • The function should return the total size of the directory, including all nested
# subdirectories.
# 2. Test the function with a sample directory structure.

# %%
def calculate_directory_size(directory):
    """
    Recursively calculate the total size of a directory.
    
    Args:
        directory (dict): Dictionary with files (int) or subdirectories (dict)
        
    Returns:
        int: Total size in KB
    """
    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):  # If value is a subdirectory
            total_size += calculate_directory_size(value)  # Recursive call
        else:
            total_size += value  # Add file size
    return total_size

# Test
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {"file3.txt": 400, "file4.txt": 100},
    "subdir2": {"subsubdir1": {"file5.txt": 250}, "file6.txt": 150}
}

print("Total directory size:", calculate_directory_size(directory_structure))
# Out:
# Total directory size: 1400

# %% [markdown]
# # 8.2.1  Dynamic Programming:
# # Task 1 - Coin Change Problem:
# Scenario: Given a set of coin denominations and a target amount, find the minimum number
# of coins needed to make the amount. If it’s not possible, return - 1.
# Task:
# 1. Write a function min_coins(coins, amount) that:
# • Uses DP to calculate the minimum number of coins needed to make up the
# amount.
# 2. Test with coins = [1, 2, 5] and amount = 11. The result should be 3 (using coins
# [5, 5, 1]).

# %%
def min_coins(coins, amount):
    """
    Find the minimum number of coins to make the given amount using DP (tabulation).
    
    Args:
        coins (list): Available coin denominations
        amount (int): Target amount
    
    Returns:
        int: Minimum number of coins, or -1 if not possible
    """
    # Initialize DP array:
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0  
    
    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)
    
    return dp[amount] if dp[amount] != float('inf') else -1

# Test
coins = [1, 2, 5]
amount = 11
print("Minimum coins needed:", min_coins(coins, amount))
# Out:
# Minimum coins needed: 3

# %% [markdown]
# # Task 2 - Longest Common Subsequence (LCS):
# Scenario: Given two strings, find the length of their longest common subsequence (LCS).
# This is useful in text comparison.
# Task:
# 1. Write a function longest_common_subsequence(s1, s2) that:
# • Uses DP to find the length of the LCS of two strings s1 and s2.
# 2. Test with strings like "abcde" and "ace"; the LCS length should be 3 ("ace").

# %%
def longest_common_subsequence(s1, s2):
    """
    Calculate the length of the LCS using DP.
    
    Args:
        s1, s2 (str): Input strings
        
    Returns:
        int: Length of the longest common subsequence
    """
    m, n = len(s1), len(s2)
    # Create DP table of size (m+1) x (n+1)
    dp = [[0]*(n+1) for _ in range(m+1)]
    
    # Fill the table
    for i in range(1, m+1):
        for j in range(1, n+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    
    return dp[m][n]

# Test
s1 = "abcde"
s2 = "ace"
print("Length of LCS:", longest_common_subsequence(s1, s2))
# Out:
# Length of LCS: 3

# %% [markdown]
# # Task 3 - 0/1 Knapsack Problem:
# Scenario: You have a list of items, each with a weight and a value. Given a weight capacity,
# maximize the total value of items you can carry without exceeding the weight capacity.
# Task:
# 1. Write a function knapsack(weights, values, capacity) that:
# • Uses DP to determine the maximum value that can be achieved within the given
# weight capacity.
#
# 2. Test with weights [1, 3, 4, 5], values [1, 4, 5, 7], and capacity 7. The re-
# sult should be 9.

# %%
def knapsack(weights, values, capacity):
    """
    Solve 0/1 Knapsack problem using DP (bottom-up approach)
    
    Args:
        weights (list): Item weights
        values (list): Item values
        capacity (int): Max weight capacity
        
    Returns:
        int: Maximum value achievable
    """
    n = len(weights)
    # DP table: dp[i][w] = max value with first i items and capacity w
    dp = [[0]*(capacity+1) for _ in range(n+1)]
    
    for i in range(1, n+1):
        for w in range(1, capacity+1):
            if weights[i-1] <= w:
                dp[i][w] = max(values[i-1] + dp[i-1][w-weights[i-1]], dp[i-1][w])
            else:
                dp[i][w] = dp[i-1][w]
    
    return dp[n][capacity]

# Test
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
print("Maximum value:", knapsack(weights, values, capacity))
# Out:
# Maximum value: 9
